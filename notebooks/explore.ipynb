# %%
import sys
sys.path.insert(0, '..')

from src.data.loader import load_session
from src.data.processor import get_lap_positions, get_driver_info
from src.viz.replay import build_replay_figure

session = load_session(2024, 'Monaco', 'R')
lap_positions = get_lap_positions(session)
driver_info = get_driver_info(session)
print(lap_positions.head(20))

# %%
fig = build_replay_figure(lap_positions, driver_info, title='2024 Monaco GP')
fig.show()
